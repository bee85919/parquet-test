# %%
###
import os
import shutil
import pandas as pd

# ###
# source_dir = './naverplace'
result_dir = './test'

# ###
# if not os.path.exists(result_dir):
#     os.makedirs(result_dir)

# ###
# for dir_name in os.listdir(source_dir):
#     if dir_name.startswith('naverplace_'):
#         dir_path = os.path.join(source_dir, dir_name)
#         for file_name in os.listdir(dir_path):
#             file_path = os.path.join(dir_path, file_name)
#             save_path = os.path.join(result_dir, file_name)
#             shutil.move(file_path, save_path)

# ###
# print("completed")

# %%
###
dir_lst = os.listdir(result_dir)

df = None
for f in dir_lst:
    if f.endswith('.parquet'):
        path = f'{result_dir}/{f}'
        p = pd.read_parquet(path)
        if df is None: df = p
        else: df = pd.concat([df, p])
df
# Out:
# /var/folders/cj/gc1ypmy136x0w5k4g3z15qy40000gn/T/ipykernel_33102/724369515.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   else: df = pd.concat([df, p])
#              id         name                                  review_keyword  \
# 0      31469297        가야한의원    (가야한의원) & (고양시 | 덕양구 | 화정동 | 한의원-일반) & 가야한의원
# 1      11665971  가온경희한의원 화정점                                 화정동 가온경희한의원 화정점
# 2      12079261        감골한의원     (감골한의원) & (안산시 | 상록구 | 사동 | 한의원-일반) & 감골한의원
# 3      11485232       감초당한의원  (감초당한의원) & (안산시 | 단원구 | 선부동 | 한의원-일반) & 감초당한의원
# 4      13234215        감초한의원          (감초한의원) & (평택시 | 진위면 | 한의원-일반) & 감초한의원
# ..          ...          ...                                             ...
# ...
